# %% [markdown]
# ## Python Exploratory Analysis

# %%
# --- 1. Importar bibliotecas ---
# pip install ...

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# --- 2. Carregar os dados CSV ---

pokemon = pd.read_csv("archive/pokemon.csv")

# %%
# --- 3. Primeira visão dos dados ---
print("📊 Tamanho das tabelas:")
print("Table (lines,cols):", pokemon.shape)
# Out:
# 📊 Tamanho das tabelas:
# Table (lines,cols): (801, 41)

# %%
# Visualizar primeiras linhas
display(pokemon.head())
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
# --- 4. Distribuição por geração ---
plt.figure(figsize=(5,3))
sns.countplot(data=pokemon, x="generation")
plt.title("Distribuição de Pokémons por Geração")
plt.show()

# %%
# --- 5. Distribuição de tipos primários ---
plt.figure(figsize=(5,3))
sns.countplot(data=pokemon, x="type1", order=pokemon["type1"].value_counts().index,)
plt.title("Distribuição dos Tipos Primários de Pokémon")
plt.xticks(rotation=45)
plt.show()

# %%
# --- 6. Média de ataque por tipo ---

# Calcular a média de ataque por tipo primário para todas as gerações
attack_mean_by_type = pokemon.groupby("type1")["attack"].mean().reset_index()

# Ordenar do maior para o menor
attack_mean_by_type = attack_mean_by_type.sort_values(by="attack", ascending=False)

# Plotar
plt.figure(figsize=(5, 3)) # Aumentei o tamanho do gráfico para acomodar mais tipos
sns.barplot(data=attack_mean_by_type, x="type1", y="attack")
plt.title("Média de Ataque por Tipo (Todas as Gerações)")
plt.ylabel("Média de Ataque")
plt.xlabel("Tipo Primário")
plt.xticks(rotation=45)
plt.show()
