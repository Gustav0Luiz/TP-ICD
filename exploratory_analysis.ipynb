# %% [markdown]
# # Nao vamos utilizar o .sqlite

# %%
# --- 1. Importar bibliotecas ---
# pip install ...

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# --- 2. Carregar os dados CSV ---
users = pd.read_csv("archive/users.csv")
campaigns = pd.read_csv("archive/campaigns.csv")
ads = pd.read_csv("archive/ads.csv")
ad_events = pd.read_csv("archive/ad_events.csv")

# %%
# --- 3. Primeira visão dos dados ---
print("📊 Tamanho das tabelas:")
print("Users:", users.shape)
print("Campaigns:", campaigns.shape)
print("Ads:", ads.shape)
print("Ad Events:", ad_events.shape)
# Out:
# 📊 Tamanho das tabelas:
# Users: (10000, 7)
# Campaigns: (50, 6)
# Ads: (200, 7)
# Ad Events: (400000, 7)

# %%
# Visualizar primeiras linhas
display(users.head())
display(campaigns.head())
display(ads.head())
display(ad_events.head())
# Out:
#   user_id user_gender  user_age age_group         country        location  \
# 0   a2474      Female        24     18-24  United Kingdom  New Mariomouth
# 1   141e5        Male        21     18-24         Germany     Danielsfort
# 2   34db0        Male        27     25-34       Australia  Vincentchester
# 3   20d08      Female        28     25-34           India        Lisaport
# 4   9e830        Male        28     25-34   United States      Brownmouth
#
#                         interests
# 0                 fitness, health
# 1        food, fitness, lifestyle
# 2                   fashion, news
# 3           health, news, finance
# 4  health, photography, lifestyle
#    campaign_id               name  start_date    end_date  duration_days  \
# 0            1  Campaign_1_Launch  2025-05-25  2025-07-23             59
# 1            2  Campaign_2_Launch  2025-04-16  2025-07-07             82
# 2            3  Campaign_3_Winter  2025-05-04  2025-06-29             56
# ...

# %%
# --- 4. Estrutura e valores ausentes ---
# aparentemente não tem dados nulos

for name, df in zip(["Users", "Campaigns", "Ads", "Ad Events"], [users, campaigns, ads, ad_events]):
    print(f"\n--- {name} ---")
    print(df.info())
    print("Valores nulos:\n", df.isna().sum())
# Out:
# --- Users ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      10000 non-null  object
#  1   user_gender  10000 non-null  object
#  2   user_age     10000 non-null  int64
#  3   age_group    10000 non-null  object
#  4   country      10000 non-null  object
#  5   location     10000 non-null  object
#  6   interests    10000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 547.0+ KB
# None
# Valores nulos:
#  user_id        0
# user_gender    0
# user_age       0
# age_group      0
# country        0
# location       0
# interests      0
# dtype: int64
#
# --- Campaigns ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
# ...

# %%
# Distribuição de idade
sns.histplot(users["user_age"], bins=20, kde=False)
plt.title("Distribuição das Idades dos Usuários")
plt.show()

# %%
# Distribuição por gênero
users["user_gender"].value_counts(normalize=True).plot(kind="bar")
plt.title("Distribuição de Gênero (%)")
plt.show()

# %%
# Países mais comuns
users["country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Países dos Usuários")
plt.show()
